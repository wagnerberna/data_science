# %%
import numpy as np
import random
from matplotlib import pyplot as plt
import pandas as pd

df = pd.read_csv(
    "C:/0-BK/0-Vscode/data_science/anhanguera/tema_3/chamados.csv",
    sep=";",
    encoding="utf-8",
)
df
# Out:
#   tecnico  chamados  tempo
# 0   Bruce        20     40
# 1   Clark        30     60
# 2   Barry        15     20

# %%
df.hist("tempo")
# Out:
# array([[<AxesSubplot: title={'center': 'tempo'}>]], dtype=object)

# %%
df.plot.line(xlabel='chamados', ylabel='tempo')
# Out:
# <AxesSubplot: xlabel='chamados', ylabel='tempo'>

# %%
df.plot.bar(xlabel='tecnico', ylabel='chamados')
# Out:
# <AxesSubplot: xlabel='tecnico', ylabel='chamados'>

# %%
df.plot.area(xlabel='tecnico', ylabel='chamados')
# Out:
# <AxesSubplot: xlabel='tecnico', ylabel='chamados'>

# %%
df.plot.pie(y='chamados')
# Out:
# <AxesSubplot: ylabel='chamados'>
